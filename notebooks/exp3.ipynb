# %% [markdown]
# # Business Intelligence Lab
# # Experiment 03
#
# ### Aim:
# To preprocess dataset using different preprocessing techniques

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading Data

# %%
df=pd.read_csv('../datasets/Bengaluru_House_Data.csv')

# %%
df.sample(5)
# Out:
#                  area_type   availability           location       size  \
# 1982        Built-up  Area  Ready To Move  Remco Bhel Layout      3 BHK
# 5890  Super built-up  Area  Ready To Move             Hebbal      2 BHK
# 7527  Super built-up  Area  Ready To Move        Koramangala      2 BHK
# 7143  Super built-up  Area         20-Dec         Whitefield      2 BHK
# 9901            Plot  Area  Ready To Move        Kodigehalli  4 Bedroom
#
#       society total_sqft  bath  balcony  price
# 1982  Suncy R       1685   2.0      1.0  110.0
# 5890  Thuse F       1200   2.0      1.0   49.0
# 7527  Proodt        1320   2.0      1.0  160.0
# 7143  Oreldhi       1173   2.0      1.0   78.2
# 9901      NaN       1320   4.0      3.0  249.0

# %% [markdown]
# ### Information about Data

# %%
#Shape of the data
df.shape
# Out:
# (13320, 9)

# %%
#Data type of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
#Mathematical columns
df.describe().T
# Out:
#            count        mean         std  min   25%   50%    75%     max
# bath     13247.0    2.692610    1.341458  1.0   2.0   2.0    3.0    40.0
# balcony  12711.0    1.584376    0.817263  0.0   1.0   2.0    2.0     3.0
# price    13320.0  112.565627  148.971674  8.0  50.0  72.0  120.0  3600.0

# %% [markdown]
# # Data preprocessing <br>
# Data preprocessing is the process of transforming raw data into an understandable format. It is also an important step in data mining as we cannot work with raw data. The quality of the data should be checked before applying machine learning or data mining algorithms.

# %% [markdown]
# ## Data Cleaning <br>
# Data Cleaning means the process of identifying the incorrect, incomplete, inaccurate, irrelevant or missing part of the data and then modifying, replacing or deleting them according to the necessity. Data cleaning is considered a foundational element of basic data science.
# Machine Learning is a data- driven AI. In machine learning, if the data is irrelevant or error-prone then it leads to an incorrect model building. As much as you make your data clean, as much as you can make a better model. So, we need to process or clean the data before using it. Without the quality data,it would be foolish to expect anything good.

# %% [markdown]
# ### Handling Missing Data <br>
# Missing data is defined as the values or data that is not stored (or not present) for some variable/s in the given dataset. In the dataset, blank shows the missing values. In Pandas, usually, missing values are represented by NaN. <br>
# Handling missing values is an important step in data cleaning that can impact model validity and reliability. <br>
# There are 2 primary ways of handling missing values:
#  - Deleting the Missing Values
#  - Imputing the Missing Values
#   - Replacing with a arbitrary/default value
#   - Replacing With Mean Value
#   - Replacing With Mode
#   - Replacing with previous value – Forward fill
#   - Replacing with next value – Backward fill

# %%
#To find the total number of null elements in each column
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %% [markdown]
# #### Location

# %%
df['location'].value_counts()
# Out:
# Whitefield                                        540
# Sarjapur  Road                                    399
# Electronic City                                   302
# Kanakpura Road                                    273
# Thanisandra                                       234
#                                                  ...
# Reliable Woods Layout                               1
# Shettihalli                                         1
# 1 Immadihalli                                       1
# 6th block banashankari 3rd stage, 100 feet ORR      1
# BEML Layout 5th Stage                               1
# Name: location, Length: 1305, dtype: int64

# %%
#Filling the NaN element with the majority ones
df['location']=df['location'].fillna('Whitefield')

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           0
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %% [markdown]
# #### Size

# %%
df['size'].value_counts()
# Out:
# 2 BHK         5199
# 3 BHK         4310
# 4 Bedroom      826
# 4 BHK          591
# 3 Bedroom      547
# 1 BHK          538
# 2 Bedroom      329
# 5 Bedroom      297
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           59
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 10 BHK           2
# 11 Bedroom       2
# 11 BHK           2
# 12 Bedroom       1
# 16 BHK           1
# 27 BHK           1
# 18 Bedroom       1
# 43 Bedroom       1
# 14 BHK           1
# 13 BHK           1
# 19 BHK           1
# Name: size, dtype: int64

# %%
#Filling the NaN element with the majority ones
df['size'] = df['size'].fillna('2 BHK')

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           0
# size               0
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %% [markdown]
# #### Society

# %%
df['society'].value_counts()
# Out:
# GrrvaGr    80
# PrarePa    76
# Prtates    59
# Sryalan    59
# GMown E    56
#            ..
# Saowsri     1
# Amais V     1
# Fosic C     1
# Wharl P     1
# Aavelis     1
# Name: society, Length: 2688, dtype: int64

# %%
#Filled the NaN values with 'Information not Available'
df['society']=df['society'].fillna('Information Not Available')

# %%
df['society'].value_counts()
# Out:
# Information Not Available    5502
# GrrvaGr                        80
# PrarePa                        76
# Prtates                        59
# Sryalan                        59
#                              ...
# Srentea                         1
# Sainei                          1
# Mantsce                         1
# Puentpa                         1
# Aavelis                         1
# Name: society, Length: 2689, dtype: int64

# %%
df.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          0
# size              0
# society           0
# total_sqft        0
# bath             73
# balcony         609
# price             0
# dtype: int64

# %% [markdown]
# #### Bath

# %%
df['bath'].value_counts()
# Out:
# 2.0     6908
# 3.0     3286
# 4.0     1226
# 1.0      788
# 5.0      524
# 6.0      273
# 7.0      102
# 8.0       64
# 9.0       43
# 10.0      13
# 12.0       7
# 11.0       3
# 13.0       3
# 16.0       2
# 14.0       1
# 40.0       1
# 18.0       1
# 27.0       1
# 15.0       1
# Name: bath, dtype: int64

# %%
#Filling the NaN values to the mode of the column which is 2.0
df["bath"]=df["bath"].fillna(df["bath"].mode()[0])

# %%
df.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          0
# size              0
# society           0
# total_sqft        0
# bath              0
# balcony         609
# price             0
# dtype: int64

# %% [markdown]
# #### Balcony

# %%
df['balcony'].value_counts()
# Out:
# 2.0    5113
# 1.0    4897
# 3.0    1672
# 0.0    1029
# Name: balcony, dtype: int64

# %%
#Filling the NaN values to the mode of the column which is 2.0
df["balcony"]=df["balcony"].fillna(df["balcony"].mode()[0])

# %%
df.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %% [markdown]
# ### Handling Outliers <br>
# An outlier is an observation that lies an abnormal distance from other values in a random sample from a population.
#
# Methods to identify outliers in the data:
# - Box plots
# - IQR method
# - Z-score method
# - ‘Distance from the mean’ method (Multivariate method) <br>
#
# Ways to handle outliers:
# - Deleting observations
# - Transforming values
# - Imputation
# - Winsorization
# - Binning

# %% [markdown]
# #### Price

# %%
Data2 = df
Data2["zscore"]=(Data2.price-Data2.price.mean())/Data2.price.std()
Data2.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#                      society total_sqft  bath  balcony   price    zscore
# 0                    Coomee        1056   2.0      1.0   39.07 -0.493353
# 1                    Theanmp       2600   5.0      3.0  120.00  0.049905
# 2  Information Not Available       1440   2.0      3.0   62.00 -0.339431
# 3                    Soiewre       1521   3.0      1.0   95.00 -0.117913
# 4  Information Not Available       1200   2.0      1.0   51.00 -0.413271

# %%
# outliers
Data2[(Data2.zscore<-4)|(Data2.zscore>4)]
# Out:
#                   area_type   availability               location        size  \
# 159              Plot  Area  Ready To Move     Mahalakshmi Layout   4 Bedroom
# 408    Super built-up  Area         19-Jan           Rajaji Nagar       7 BHK
# 605    Super built-up  Area         19-Jan           Malleshwaram       7 BHK
# 743    Super built-up  Area  Ready To Move        Cunningham Road       4 BHK
# 1044             Plot  Area  Ready To Move           Binnamangala   6 Bedroom
# ...                     ...            ...                    ...         ...
# 12987            Plot  Area  Ready To Move       Dodsworth Layout   6 Bedroom
# 13067            Plot  Area  Ready To Move         Defence Colony  10 Bedroom
# 13086  Super built-up  Area  Ready To Move          Sindhi Colony       5 BHK
# 13197            Plot  Area  Ready To Move  Ramakrishnappa Layout   4 Bedroom
# 13200            Plot  Area  Ready To Move         Defence Colony   6 Bedroom
#
#                          society total_sqft  bath  balcony   price     zscore
# 159    Information Not Available       3750   4.0      0.0   760.0   4.346023
# 408    Information Not Available      12000   6.0      3.0  2200.0  14.012291
# 605    Information Not Available      12000   7.0      3.0  2200.0  14.012291
# 743    Information Not Available       5270   4.0      3.0  1250.0   7.635239
# 1044   Information Not Available       3968   5.0      2.0   900.0   5.285799
# ...                          ...        ...   ...      ...     ...        ...
# 12987  Information Not Available      30400   4.0      2.0  1824.0  11.488321
# 13067  Information Not Available       7150  13.0      2.0  3600.0  23.410050
# 13086                    HMeuran    5665.84   7.0      2.0   988.0   5.876516
# 13197  Information Not Available       9200   4.0      2.0  2600.0  16.697365
# 13200  Information Not Available       8000   6.0      3.0  2800.0  18.039902
#
# [107 rows x 10 columns]

# %%
# Remove the outliers from the Data points
Data4= Data2[(Data2.zscore>-4)&(Data2.zscore<4)]
df = Data4.drop('zscore', axis='columns')
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size                    society total_sqft  bath  balcony   price
# 0          2 BHK                    Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom                    Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK  Information Not Available       1440   2.0      3.0   62.00
# 3          3 BHK                    Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK  Information Not Available       1200   2.0      1.0   51.00
# ...          ...                        ...        ...   ...      ...     ...
# 13315  5 Bedroom                    ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK  Information Not Available       3600   5.0      2.0  400.00
# 13317      2 BHK                    Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK                    SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK  Information Not Available        550   1.0      1.0   17.00
#
# [13213 rows x 9 columns]

# %% [markdown]
# #### Size

# %%
#Removing BHK,bedroom and RK from the 'size' column
df['size']=df['size'].str.split().str[0]
#Converting the data type of 'size' column to int32 to remove the decimal point
df['size']=df['size'].astype('int32')
df['size']
# Out:
# 0        2
# 1        4
# 2        3
# 3        3
# 4        2
#         ..
# 13315    5
# 13316    4
# 13317    2
# 13318    4
# 13319    1
# Name: size, Length: 13213, dtype: int32

# %%
sns.boxplot(df['size'])
# Out:
# <AxesSubplot:>

# %%
#Removing the outliers which are more than 10
df=df.drop(df[df['size']>10].index)

# %%
sns.boxplot(df['size'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Bath

# %%
sns.boxplot(df['bath'])
# Out:
# <AxesSubplot:>

# %%
#Removing the outliers
df=df.drop(df[df['bath']>5].index)

# %%
sns.boxplot(df['bath'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data Transformation <br>
# Data transformation is the process of converting raw data into a format or structure that would be more suitable for model building and also data discovery in general. It is an imperative step in feature engineering that facilitates discovering insights.
# <br>
# ### Label Encoding
# This approach is very simple and it involves converting each value in a column to a number. Consider a dataset of bridges having a column named bridge-types having below values. Though there will be many more columns in the dataset, to understand label-encoding, we will focus on one categorical column only. <br>
# preprocessing.LabelEncoder() of sklearn is used for label encoding.<br>
# In our dataset we use this on Vehicle Style and Model
#
# ### One-Hot Encoder
# Though label encoding is straight, it has the disadvantage that the numeric values can be misinterpreted by algorithms as having some sort of hierarchy/order in them. This ordering issue is addressed in another common alternative approach called ‘One-Hot Encoding’. In this strategy, each category value is converted into a new column and assigned a 1 or 0 (notation for true/false) value to the column. Let’s consider the previous example of bridge type and safety levels with one-hot encoding.<br>
# In our dataset we use this on Transmission Type and Vehicle Size

# %% [markdown]
# ### One-Hot Encoding for Area Type

# %%
df = df
dummies = pd.get_dummies(df.area_type)
dummies.head(3)
# Out:
#    Built-up  Area  Carpet  Area  Plot  Area  Super built-up  Area
# 0               0             0           0                     1
# 1               0             0           1                     0
# 2               1             0           0                     0

# %%
df1 = pd.concat([df,dummies], axis='columns')
df = df1.drop('area_type', axis='columns')
df
# Out:
#         availability                  location  size  \
# 0             19-Dec  Electronic City Phase II     2
# 1      Ready To Move          Chikka Tirupathi     4
# 2      Ready To Move               Uttarahalli     3
# 3      Ready To Move        Lingadheeranahalli     3
# 4      Ready To Move                  Kothanur     2
# ...              ...                       ...   ...
# 13315  Ready To Move                Whitefield     5
# 13316  Ready To Move             Richards Town     4
# 13317  Ready To Move     Raja Rajeshwari Nagar     2
# 13318         18-Jun           Padmanabhanagar     4
# 13319  Ready To Move              Doddathoguru     1
#
#                          society total_sqft  bath  balcony   price  \
# 0                        Coomee        1056   2.0      1.0   39.07
# 1                        Theanmp       2600   5.0      3.0  120.00
# 2      Information Not Available       1440   2.0      3.0   62.00
# 3                        Soiewre       1521   3.0      1.0   95.00
# 4      Information Not Available       1200   2.0      1.0   51.00
# ...                          ...        ...   ...      ...     ...
# 13315                    ArsiaEx       3453   4.0      0.0  231.00
# 13316  Information Not Available       3600   5.0      2.0  400.00
# 13317                    Mahla T       1141   2.0      1.0   60.00
# 13318                    SollyCl       4689   4.0      1.0  488.00
# 13319  Information Not Available        550   1.0      1.0   17.00
#
#        Built-up  Area  Carpet  Area  Plot  Area  Super built-up  Area
# 0                   0             0           0                     1
# 1                   0             0           1                     0
# 2                   1             0           0                     0
# 3                   0             0           0                     1
# 4                   0             0           0                     1
# ...               ...           ...         ...                   ...
# 13315               1             0           0                     0
# 13316               0             0           0                     1
# 13317               1             0           0                     0
# 13318               0             0           0                     1
# 13319               0             0           0                     1
#
# [12724 rows x 12 columns]

# %% [markdown]
# ### Data Normalization
# Feature scaling refers to putting the values in the same range or same scale so that no variable is dominated by the other.
#
# Numerical data in the dataset can have a varied range i.e. one parameter may lie between 1 to 10 for all records whereas another parameter can lie between 1000 to 5000. Though data is logically correct but after passing to a particular algorithm, the features with higher magnitude become key parameters for that algorithm.
#
# To avoid such situations feature scaling is performed using some statistical techniques like Min-Max scaling & Mean normalization. This creates a common range for all the parameters and thus removes Algorithmic bias.
#
# Normalization is a scaling technique in which values are shifted and rescaled so that they end up ranging between 0 and 1. It is also known as Min-Max scaling.

# %%
from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

df1 = df[['size','bath','balcony','price']]
df_minmax = min_max_scaler.fit_transform(df1)

# %%
pd.DataFrame(df_minmax)
# Out:
#            0     1         2         3
# 0      0.125  0.25  0.333333  0.044899
# 1      0.375  1.00  1.000000  0.161850
# 2      0.250  0.25  1.000000  0.078035
# 3      0.250  0.50  0.333333  0.125723
# 4      0.125  0.25  0.333333  0.062139
# ...      ...   ...       ...       ...
# 12719  0.500  0.75  0.000000  0.322254
# 12720  0.375  1.00  0.666667  0.566474
# 12721  0.125  0.25  0.333333  0.075145
# 12722  0.375  0.75  0.333333  0.693642
# 12723  0.000  0.00  0.333333  0.013006
#
# [12724 rows x 4 columns]

# %% [markdown]
# ### Z-Score Transformation
# In statistics, a z-score tells us how many standard deviations away a value is from the mean. We use the following formula to calculate a z-score:
#
# z = (X – μ) / σ
#
# where:
#
# X is a single raw data value <br>
# μ is the population mean<br>
# σ is the population standard deviation

# %%
import scipy.stats as stats
df1 = df[['size','bath','balcony','price']]
pd.DataFrame(stats.zscore(df1))
# Out:
#            size      bath   balcony     price
# 0     -0.709340 -0.560298 -0.742703 -0.670044
# 1      1.517289  2.809435  1.774317  0.237696
# 2      0.403975 -0.560298  1.774317 -0.412853
# 3      0.403975  0.562946 -0.742703 -0.042713
# 4     -0.709340 -0.560298 -0.742703 -0.536233
# ...         ...       ...       ...       ...
# 13315  2.630603  1.686191 -2.001213  1.482712
# 13316  1.517289  2.809435  0.515807  3.378276
# 13317 -0.709340 -0.560298 -0.742703 -0.435285
# 13318  1.517289  1.686191 -0.742703  4.365316
# 13319 -1.822654 -1.683542 -0.742703 -0.917589
#
# [12724 rows x 4 columns]

# %% [markdown]
# ### Data Reduction
# **Dimensionality Reduction** <br>
# Any location having less than 10 data points should be tagged as "other" location. This way number of categories can be reduced by huge amount. Later on when we do one hot encoding, it will help us with having fewer dummy columns

# %%
df1 = df
location_stats = df1['location'].value_counts(ascending=False)
location_stats
# Out:
# Whitefield              532
# Sarjapur  Road          387
# Electronic City         301
# Kanakpura Road          269
# Thanisandra             231
#                        ...
# NTI Layout                1
# Maruthi nagar kogilu      1
# Gaundanapalya             1
# Hommadevanahalli          1
# Venkateswara Nagar        1
# Name: location, Length: 1257, dtype: int64

# %%
len(df1.location.unique())
# Out:
# 1257

# %%
location_stats_less_than_10 = location_stats[location_stats<=10]
location_stats_less_than_10
# Out:
# Nagadevanahalli         10
# Vishwapriya Layout      10
# Nagasandra              10
# LB Shastri Nagar        10
# Gunjur Palya            10
#                         ..
# NTI Layout               1
# Maruthi nagar kogilu     1
# Gaundanapalya            1
# Hommadevanahalli         1
# Venkateswara Nagar       1
# Name: location, Length: 1028, dtype: int64

# %%
df.location = df.location.apply(lambda x: 'other' if x in location_stats_less_than_10 else x)
len(df.location.unique())
# Out:
# 230
